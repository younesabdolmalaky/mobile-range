# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
X = df.iloc[:,df.columns != 'price_range']
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y = Target.to_numpy()
Y
# Out:
# array([1, 2, 2, ..., 3, 0, 3])

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
neigh = KNeighborsClassifier(n_neighbors=10 , weights='distance' , algorithm='kd_tree',leaf_size=20 )
neigh.fit(X[:1500], Y[:1500])
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=20, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='distance')

# %%
p = neigh.predict(X[1500:])
e = Y[1500:]
print(metrics.classification_report(e,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       125
#            1       0.88      0.95      0.91       128
#            2       0.93      0.85      0.89       126
#            3       0.94      0.94      0.94       121
#
#     accuracy                           0.93       500
#    macro avg       0.93      0.93      0.93       500
# weighted avg       0.93      0.93      0.93       500
