# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Conv1D , MaxPool1D , Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(df.iloc[: , :-1])
data
# Out:
# array([[0.22778891, 0.        , 0.68      , ..., 0.        , 0.        ,
#         1.        ],
#        [0.34736139, 1.        , 0.        , ..., 1.        , 1.        ,
#         0.        ],
#        [0.04141617, 1.        , 0.        , ..., 1.        , 1.        ,
#         0.        ],
#        ...,
#        [0.94188377, 0.        , 0.16      , ..., 1.        , 1.        ,
#         0.        ],
#        [0.6753507 , 0.        , 0.16      , ..., 1.        , 1.        ,
#         1.        ],
#        [0.00601202, 1.        , 0.6       , ..., 1.        , 1.        ,
#         1.        ]])

# %%
X = data
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
np.shape(X_train)
# Out:
# (1500, 20)

# %%
X_train = np.expand_dims(X_train, axis=2)
X_test = np.expand_dims(X_test, axis=2)
X_train
# Out:
# array([[[0.00668003],
#         [0.        ],
#         [0.16      ],
#         ...,
#         [1.        ],
#         [0.        ],
#         [0.        ]],
#
#        [[0.09352037],
#         [1.        ],
#         [0.24      ],
#         ...,
#         [1.        ],
#         [1.        ],
#         [1.        ]],
#
#        [[0.20307281],
#         [0.        ],
#         [0.12      ],
#         ...,
#         [1.        ],
#         [0.        ],
#         [1.        ]],
#
#        ...,
#
#        [[0.88710755],
#         [1.        ],
#         [0.        ],
#         ...,
#         [1.        ],
#         [0.        ],
#         [1.        ]],
#
#        [[0.95257181],
#         [0.        ],
#         [0.16      ],
#         ...,
#         [0.        ],
#         [1.        ],
#         [1.        ]],
#
#        [[0.08951236],
#         [1.        ],
#         [0.04      ],
#         ...,
#         [1.        ],
#         [0.        ],
#         [0.        ]]])

# %%
model = Sequential([
    Conv1D(32, 3, activation='relu' , input_shape=(20,1)),
    Conv1D(64, 3, activation='relu'),
    Conv1D(128, 3, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Flatten(),
    Dense(4, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 18, 32)            128
#
#  conv1d_1 (Conv1D)           (None, 16, 64)            6208
#
#  conv1d_2 (Conv1D)           (None, 14, 128)           24704
#
#  dense (Dense)               (None, 14, 256)           33024
#
#  dense_1 (Dense)             (None, 14, 128)           32896
#
#  flatten (Flatten)           (None, 1792)              0
#
#  dense_2 (Dense)             (None, 4)                 7172
#
# ...
# Total params: 104,132
# Trainable params: 104,132
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
y_train_ohe = to_categorical(y_train)
y_test_ohe = to_categorical(y_test)

# %%
model.fit(X_train, y_train_ohe, epochs=10, validation_data=(X_test, y_test_ohe), batch_size=40)
model.fit(X_train, y_train_ohe, epochs=10, validation_data=(X_test, y_test_ohe), batch_size=60)
model.fit(X_train, y_train_ohe, epochs=10, validation_data=(X_test, y_test_ohe), batch_size=80)
model.fit(X_train, y_train_ohe, epochs=10, validation_data=(X_test, y_test_ohe), batch_size=100)
model.fit(X_train, y_train_ohe, epochs=10, validation_data=(X_test, y_test_ohe), batch_size=150)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 1s 31ms/step - loss: 0.4256 - accuracy: 0.8160 - val_loss: 0.4970 - val_accuracy: 0.7860
# Epoch 2/10
# 38/38 [==============================] - 1s 28ms/step - loss: 0.4054 - accuracy: 0.8247 - val_loss: 0.4659 - val_accuracy: 0.7900
# Epoch 3/10
# 38/38 [==============================] - 1s 27ms/step - loss: 0.3822 - accuracy: 0.8387 - val_loss: 0.5900 - val_accuracy: 0.7340
# Epoch 4/10
# 38/38 [==============================] - 1s 26ms/step - loss: 0.4191 - accuracy: 0.8047 - val_loss: 0.5060 - val_accuracy: 0.7800
# Epoch 5/10
# 38/38 [==============================] - 1s 30ms/step - loss: 0.3796 - accuracy: 0.8453 - val_loss: 0.5496 - val_accuracy: 0.7620
# Epoch 6/10
# 38/38 [==============================] - 1s 27ms/step - loss: 0.3623 - accuracy: 0.8473 - val_loss: 0.4654 - val_accuracy: 0.8000
# Epoch 7/10
# ...
