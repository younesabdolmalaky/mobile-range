# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../datasets/train.csv')
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
X = df.iloc[:,df.columns != 'price_range']
Y = df['price_range'].to_numpy()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'n_neighbors':range(0, 20),
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
     'weights':['distance' , 'uniform'],
    'p':[1, 2],
}

KNN = KNeighborsClassifier()
clf = GridSearchCV(KNN, parameters ,n_jobs = -1 ,scoring = 'accuracy' , cv = 5 , verbose=4)

# %%
clf.fit(X[:1500],Y[:1500])
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 1570 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done 1600 out of 1600 | elapsed:   44.1s finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': range(0, 20), 'p': [1, 2],
#                          'weights': ['distance', 'uniform']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=4)

# %%
p = clf.predict(X[1500:])
e = Y[1500:]
print(metrics.classification_report(e,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       125
#            1       0.86      0.93      0.89       128
#            2       0.92      0.81      0.86       126
#            3       0.92      0.95      0.93       121
#
#     accuracy                           0.91       500
#    macro avg       0.91      0.91      0.91       500
# weighted avg       0.91      0.91      0.91       500

# %%
from sklearn.model_selection import RandomizedSearchCV

parameters = {
    'n_neighbors':range(0, 100),
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
     'weights':['distance' , 'uniform'],
    'p':[1, 2],
    'leaf_size' : range(10 , 120)
}

KNN = KNeighborsClassifier()
clf = RandomizedSearchCV(KNN, parameters ,n_jobs = -1 ,scoring = 'f1_macro' , cv = 6 , verbose=4 , random_state=0 ,n_iter =100)

# %%
clf.fit(X[:1500],Y[:1500])
# Out:
# Fitting 6 folds for each of 100 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:   16.8s finished
# RandomizedSearchCV(cv=6, error_score=nan,
#                    estimator=KNeighborsClassifier(algorithm='auto',
#                                                   leaf_size=30,
#                                                   metric='minkowski',
#                                                   metric_params=None,
#                                                   n_jobs=None, n_neighbors=5,
#                                                   p=2, weights='uniform'),
#                    iid='deprecated', n_iter=100, n_jobs=-1,
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'leaf_size': range(10, 120),
#                                         'n_neighbors': range(0, 100),
#                                         'p': [1, 2],
#                                         'weights': ['distance', 'uniform']},
#                    pre_dispatch='2*n_jobs', random_state=0, refit=True,
#                    return_train_score=False, scoring='f1_macro', verbose=4)

# %%
p = clf.predict(X[1500:])
e = Y[1500:]
print(metrics.classification_report(e,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       125
#            1       0.87      0.93      0.90       128
#            2       0.92      0.82      0.87       126
#            3       0.93      0.95      0.94       121
#
#     accuracy                           0.92       500
#    macro avg       0.92      0.92      0.92       500
# weighted avg       0.92      0.92      0.92       500
